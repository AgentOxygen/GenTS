# %%
from timeseries_generation import ModelOutputDatabase
from dask.distributed import Client, LocalCluster


cluster = LocalCluster(
    n_workers=1,
    processes=1,
    threads_per_worker=1,
    memory_limit="2GB",
    dashboard_address="localhost:8001"
)

cluster.scale(100)
client = Client(cluster)
client
# Out:
# Creating cluster...
# <Client: 'tcp://127.0.0.1:37235' processes=100 threads=100, memory=186.26 GiB>

# %%
test_db = ModelOutputDatabase(
    hf_head_dir="/local1/testing_timeseries/history_files/",
    ts_head_dir="/local1/testing_timeseries/output/",
)
ts_paths_and_timings = test_db.run()

# %%
test_db = ModelOutputDatabase(
    hf_head_dir="/local1/testing_timeseries/history_files/v21.LR.BSMYLEsmbb.1970-05.001/archive.001",
    ts_head_dir="/local1/testing_timeseries/output/archive.001-special",
    dir_name_swaps = {"hist": "proc/tseries"},
    file_exclusions = [".h2."],
    dir_exclusions = ["rest", "logs"],
    timeseries_year_length = 1,
    overwrite = True,
    include_variables = None,
    exclude_variables = None,
    compression_level = 4,
    variable_compression_levels = {"FIRA": 0, "SNOW": 2}
)
ts_paths_and_timings = test_db.run()
# Out:
# Initializing...
# Searching tree for netCDF files: '/local1/testing_timeseries/history_files/v21.LR.BSMYLEsmbb.1970-05.001/archive.001'
# 	Done.
# Grouping history files...
# Done.
# Building arguments.
# Starting Build.
# Dask client detected.
# 	Gathering metadata...
# 	Done.
# 	Computing timeseries arguments...
# 	Done.
# Build complete.
# Dask client detected, mapping arguments to generateTimeSeries() in parallel.
# Map complete, awaiting cluster computation...
# 	Done.

# %%
/local1/testing_timeseries/output/archive.001-special/atm/proc/tseries/month_1/v21.LR.BSMYLEsmbb.1970-05.001.eam.h0.

# %%
path = "/local1/testing_timeseries/output/archive.001-special/atm/proc/tseries/month_1/v21.LR.BSMYLEsmbb.1970-05.001.eam.h0."
test_db.getTimeSeriesGroups()[path]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 2
#       1 path = "/local1/testing_timeseries/output/archive.001-special/atm/proc/tseries/month_1/v21.LR.BSMYLEsmbb.1970-05.001.eam.h0."
# ----> 2 test_db.getTimeSeriesGroups()[path]
#
# KeyError: '/local1/testing_timeseries/output/archive.001-special/atm/proc/tseries/month_1/v21.LR.BSMYLEsmbb.1970-05.001.eam.h0.'
